# %%
import sys
sys.path.append('..')

# %%
from llm_wrapper import get_chat_llm, get_embeddings
from pdf_parsing import VectorStoreManager, RAGAgent
from langchain.agents import create_agent
from langchain.tools import tool
from db_agent import SQLAgent

# %%
from opik.integrations.langchain import OpikTracer

# %%
embeddings = get_embeddings()
llm = get_chat_llm()
# Out:
# Warning: Could not configure Opik tracing: API key must be set to check workspace name.
# ✓ Opik tracer initialized for project: customer-support

# %%
vector_store_manager = VectorStoreManager(
    embeddings=embeddings,
    collection_name="smart_scribble_docs"
)

rag_agent = RAGAgent(llm, vector_store_manager, k=3)

# %%
rag_agent.agent.invoke({
    'messages': ['give me technical spefications of the product in 30 words']
})
# Out:
# {'messages': [HumanMessage(content='give me technical spefications of the product in 30 words', additional_kwargs={}, response_metadata={}, id='87d5ab01-1d14-4a59-bbf7-43f7c5116c6a'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 99, 'total_tokens': 121, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_3dcd5944f5', 'id': 'chatcmpl-CjeMJdheJfY7gCfbNlkdjqMG8P2v7', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='lc_run--6aa74a9a-54fd-4570-858c-22eff52c11d7-0', tool_calls=[{'name': 'retriever_tool', 'args': {'user_query': 'technical specifications of the product'}, 'id': 'call_i74KVBFxZLkeF49xpMDLP2sg', 'type': 'tool_call'}], usage_metadata={'input_tokens': 99, 'output_tokens': 22, 'total_tokens': 121, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='<table>\n<tr>\n<td>Category</td>\n<td>Specification</td>\n</tr>\n<tr>\n<td>Display</td>\n<td>10.3-inch CanvasInk™ E-Ink Display (Monochrome)</td>\n</tr>\n<tr>\n<td>Resolution</td>\n<td>(1872 \\times 14041) (227 DPI)</td>\n</tr>\n<tr>\n<td>Processor</td>\n<td>Quad-Core 1.8GHz ARM Cortex Processor</td>\n</tr>\n<tr>\n<td>Storage</td>\n<td>(64GBI) Internal Storage (Non-expandable)</td>\n</tr>\n<tr>\n<td>RAM</td>\n<td>(4GBI) LPDDR4X</td>\n</tr>\n<tr>\n<td>Connectivity</td>\n<td>Wi-Fi (\\(2.4GHz + 5GHzl)), Bluetooth 5.0, USB-C</td>\n</tr>\n<tr>\n<td>Battery</td>\n<td>\\(3000mAhl) Li-lon (Up to 2 weeks standby, 10 hours active writing)</td>\n</tr>\n<tr>\n<td>Stylus</td>\n<td>Wacom EMR Technology (Battery-free), 4096 Pressure Levels</td>\n</tr>\n<tr>\n<td>Dimensions</td>\n<td>\\(230mm Itimes 190mm \\times 5.8mml)</td>\n</tr>\n<tr>\n<td>Weight</td>\n<td>(395g\\)</td>\n</tr>\n<tr>\n<td>OS</td>\n<td>SmartOS (Based on Linux Kernel)</td>\n</tr>\n</table>  \nFile Formats PDF, EPUB, TXT, PNG, SVG  \n<!-- PageBreak --> · Chassis: Machined from an aerospace-grade aluminum alloy for rigidity and lightness.  \n· Thickness: At just \\\\(5.8mml), it is thinner than a typical smartphone and slides easily into any folio or bag.  \n· Weight: Weighing under \\\\(400gl), it is comfortable to hold in one hand for extended reading or reviewing\nsessions. 1\\. Draft a specific email marketing campaign targeting university students for this product?  \n2\\. Create a User Manual section regarding how to use the specific "AI Expand" gestures?  \n3\\. Generate a comparison table comparing SmartScribble to competitors like reMarkable or Kindle Scribe?', name='retriever_tool', id='85ad66b0-da45-45b6-9138-8c13ab669b3b', tool_call_id='call_i74KVBFxZLkeF49xpMDLP2sg'),
#   AIMessage(content='The product features a 10.3-inch CanvasInk E-Ink display with 227 DPI, a quad-core 1.8GHz ARM Cortex processor, 64GB storage, 4GB RAM, Wi-Fi, Bluetooth 5.0, USB-C, 3000mAh battery, Wacom EMR stylus, and runs SmartOS.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 621, 'total_tokens': 696, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_3dcd5944f5', 'id': 'chatcmpl-CjeMLjCvdLZcW21lKwa6VKxyXFFjy', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--038257a9-0728-446f-8473-db1bd9ae14fb-0', usage_metadata={'input_tokens': 621, 'output_tokens': 75, 'total_tokens': 696, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
sql_agent = SQLAgent(llm, dialect="Postgres", top_k=5)
sql_agent.agent.invoke({
    'messages': ['summarize the feedbacks of product with ratings less than or equal to 3.']
})
# Out:
# {'messages': [HumanMessage(content='summarize the feedbacks of product with ratings less than or equal to 3.', additional_kwargs={}, response_metadata={}, id='cc350566-a971-43e0-9566-0f2e816edf6c'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 562, 'total_tokens': 575, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_3dcd5944f5', 'id': 'chatcmpl-CjeTSWnn7biqTcnOVMEoVHCGXQNia', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='lc_run--bb3f2e32-803b-40fa-8017-4ca7499c5471-0', tool_calls=[{'name': 'sql_db_list_tables', 'args': {}, 'id': 'call_DY6ZkIKi4bAVWInw78DOFmYt', 'type': 'tool_call'}], usage_metadata={'input_tokens': 562, 'output_tokens': 13, 'total_tokens': 575, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='customers, inventory_logs, langchain_pg_collection, langchain_pg_embedding, orders, product_reviews, products, promotions, returns, shipments, support_tickets, ticket_messages', name='sql_db_list_tables', id='f64f49fc-14a5-42d3-bd2f-2ce9646ed10e', tool_call_id='call_DY6ZkIKi4bAVWInw78DOFmYt'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 618, 'total_tokens': 636, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_3dcd5944f5', 'id': 'chatcmpl-CjeTSmjvYJA8HRkqUgs9HUkNDon1K', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='lc_run--2c914edc-f0f9-4558-9c3b-0acdf207a824-0', tool_calls=[{'name': 'sql_db_schema', 'args': {'table_names': 'product_reviews'}, 'id': 'call_djOlZO1sRUzb1alhAOygriHT', 'type': 'tool_call'}], usage_metadata={'input_tokens': 618, 'output_tokens': 18, 'total_tokens': 636, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="\nCREATE TABLE product_reviews (\n\treview_id SERIAL NOT NULL, \n\tproduct_id INTEGER NOT NULL, \n\tcustomer_id INTEGER NOT NULL, \n\torder_id INTEGER, \n\trating INTEGER NOT NULL, \n\treview_title VARCHAR(255), \n\treview_text TEXT, \n\tis_verified_purchase BOOLEAN DEFAULT false, \n\thelpful_count INTEGER DEFAULT 0, \n\treported_count INTEGER DEFAULT 0, \n\tstatus VARCHAR(20) DEFAULT 'pending'::character varying, \n\tcreated_at TIMESTAMP WITHOUT TIME ZONE DEFAULT CURRENT_TIMESTAMP, \n\tupdated_at TIMESTAMP WITHOUT TIME ZONE DEFAULT CURRENT_TIMESTAMP, \n\tCONSTRAINT product_reviews_pkey PRIMARY KEY (review_id), \n\tCONSTRAINT product_reviews_customer_id_fkey FOREIGN KEY(customer_id) REFERENCES customers (customer_id), \n\tCONSTRAINT product_reviews_order_id_fkey FOREIGN KEY(order_id) REFERENCES orders (order_id), \n\tCONSTRAINT product_reviews_product_id_fkey FOREIGN KEY(product_id) REFERENCES products (product_id), \n\tCONSTRAINT product_reviews_rating_check CHECK (rating >= 1 AND rating <= 5), \n\tCONSTRAINT product_reviews_status_check CHECK (status::text = ANY (ARRAY['pending'::character varying, 'approved'::character varying, 'rejected'::character varying]::text[]))\n)\n\n/*\n3 rows from product_reviews table:\nreview_id\tproduct_id\tcustomer_id\torder_id\trating\treview_title\treview_text\tis_verified_purchase\thelpful_count\treported_count\tstatus\tcreated_at\tupdated_at\n1\t1\t1\t1\t5\tLife-changing productivity tool!\tI've been using this for 3 months and it's transformed how I take notes. The AI features are incredi\tTrue\t45\t0\tapproved\t2024-02-01 10:00:00\t2025-11-30 06:32:19.289733\n2\t1\t3\t10\t5\tPerfect for artists\tThe pressure sensitivity is amazing. I can sketch just like on paper but with all the digital benefi\tTrue\t32\t0\tapproved\t2024-04-10 15:30:00\t2025-11-30 06:32:19.289733\n3\t1\t5\t19\t4\tGreat for students\tLove it for taking lecture notes. OCR works really well. Only wish battery lasted longer.\tTrue\t28\t0\tapproved\t2024-06-05 09:15:00\t2025-11-30 06:32:19.289733\n*/", name='sql_db_schema', id='86bcd604-b0f7-4d97-b24e-976de1a903d2', tool_call_id='call_djOlZO1sRUzb1alhAOygriHT'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 1167, 'total_tokens': 1200, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_3dcd5944f5', 'id': 'chatcmpl-CjeTTdJxxp0Ii7Ee79lMMXO3HbR5b', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='lc_run--8ab83fcd-765f-42da-b1b7-57ed3c39c751-0', tool_calls=[{'name': 'sql_db_query', 'args': {'query': 'SELECT review_title, review_text FROM product_reviews WHERE rating <= 3 LIMIT 5;'}, 'id': 'call_Nx9b5CYx4QpntmY8totz6dTD', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1167, 'output_tokens': 33, 'total_tokens': 1200, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="[('Good but pricey', 'Works as advertised but $299 is steep. Worth it if you write a lot.')]", name='sql_db_query', id='2917739d-e370-4755-946e-33ef2a1b1c85', tool_call_id='call_Nx9b5CYx4QpntmY8totz6dTD'),
#   AIMessage(content='There is one feedback with a rating less than or equal to 3: "Good but pricey" - The user mentioned that the product works as advertised but finds the price of $299 steep, suggesting it is worth it only if you write a lot.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 1233, 'total_tokens': 1286, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_3dcd5944f5', 'id': 'chatcmpl-CjeTTvFcbehVWts5sSzkVzP50QXG4', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--3ef04b77-b3ef-42cf-aa4a-cd302c930c00-0', usage_metadata={'input_tokens': 1233, 'output_tokens': 53, 'total_tokens': 1286, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
from langgraph.types import Command, interrupt

@tool
def rag_tool(query: str) -> str:
    """Tool to answer product related queries using RAG agent."""
    return rag_agent.agent.invoke({'messages': [query]})['messages'][-1].content

@tool
def sql_tool(query: str) -> str:
    """Tool to answer transactions questions from the user, this tool will be able to generate the sql query and respond
        query -> str : user query ex. 'summarize the feedbacks of product with ratings less than or equal to 3.'
    """
    return sql_agent.agent.invoke({'messages': [query]})['messages'][-1].content


@tool
def get_human_feedback(query: str) -> str:
    """Tool to get human feedback for queries not answered by other agents or tools."""
    response = interrupt({
        "type": "human_feedback",
        "query": query
    })
    return response

# %%
from langgraph.checkpoint.memory import InMemorySaver

supervisor_agent = create_agent(
    llm, 
    tools=[rag_tool, sql_tool, get_human_feedback],
    checkpointer=InMemorySaver(),
    system_prompt="You are a helpful customer support assistant. Use the available tools to answer user queries effectively. If unsure or not getting relevant response from existing tools, seek human feedback."
    )

# %%
tracer = OpikTracer(graph=supervisor_agent.get_graph(xray=True))

# %%
repsonse = supervisor_agent.invoke({
    'messages': ['Provide an overview of the technical specifications and summarize customer feedback from the database.']
}, config={
        "callbacks": [tracer], 
    })
# Out:
# OPIK: You are attempting to log data into a nested span under the project name "customer-support". However, the project name "Default Project" from parent span will be used instead.
# OPIK: You are attempting to log data into a nested span under the project name "customer-support". However, the project name "Default Project" from parent span will be used instead.
# OPIK: You are attempting to log data into a nested span under the project name "customer-support". However, the project name "Default Project" from parent span will be used instead.
# OPIK: You are attempting to log data into a nested span under the project name "customer-support". However, the project name "Default Project" from parent span will be used instead.
# OPIK: You are attempting to log data into a nested span under the project name "customer-support". However, the project name "Default Project" from parent span will be used instead.
# OPIK: You are attempting to log data into a nested span under the project name "customer-support". However, the project name "Default Project" from parent span will be used instead.
# OPIK: You are attempting to log data into a nested span under the project name "customer-support". However, the project name "Default Project" from parent span will be used instead.
# OPIK: You are attempting to log data into a nested span under the project name "customer-support". However, the project name "Default Project" from parent span will be used instead.
# OPIK: You are attempting to log data into a nested span under the project name "customer-support". However, the project name "Default Project" from parent span will be used instead.
# OPIK: You are attempting to log data into a nested span under the project name "customer-support". However, the project name "Default Project" from parent span will be used instead.

# %%
print(repsonse['messages'][-1].content)
# Out:
# The device has the following technical specifications:
# - 10.3-inch CanvasInk™ E-Ink Display (Monochrome) with a resolution of 1872 × 1404 (227 DPI)
# - Quad-Core 1.8GHz ARM Cortex Processor
# - 64GB Internal Storage (Non-expandable)
# - 4GB LPDDR4X RAM
# - Connectivity options include Wi-Fi (2.4GHz + 5GHz), Bluetooth 5.0, and USB-C
# - 3000mAh Li-ion Battery offering up to 2 weeks standby and 10 hours of active writing
# - Wacom EMR Technology Stylus (Battery-free) with 4096 Pressure Levels
# - Dimensions: 230mm × 190mm × 5.8mm; Weight: 395g
# - OS: SmartOS (Based on Linux Kernel)
# - Supports file formats such as PDF, EPUB, TXT, PNG, and SVG
# - Additional features include aerospace-grade aluminum alloy chassis, bi-directional sync with platforms like Google Drive, OneNote, Evernote, Dropbox, and OneDrive
#
# Customer feedback summary:
# - Mostly high ratings (4-5 stars) praising features
# - Positive feedback on pressure sensitivity for artists, useful AI features, effective OCR, and overall performance
# - Appreciated for business meetings and brainstorming utility
# - Some mention the price is steep but justified with extensive use
# - Suggestions include keeping extra stylus backups and improving battery life
#
# If you would like more detailed feedback or specific reviews, please let me know!

# %%
config = {"configurable": {"thread_id": "1"}, "callbacks": [tracer]}

response = supervisor_agent.invoke({
    'messages': ['what is the weather in mumbai']
}, config=config)
# Out:
# OPIK: You are attempting to log data into a nested span under the project name "customer-support". However, the project name "Default Project" from parent span will be used instead.

# %%
response
# Out:
# {'messages': [HumanMessage(content='what is the weather in mumbai', additional_kwargs={}, response_metadata={}, id='26864288-d5bc-44d4-8fd6-f810be479535'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 183, 'total_tokens': 206, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_3dcd5944f5', 'id': 'chatcmpl-CjflxVVfvG7jwW2PPM7mdi4AxdQQY', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='lc_run--15829850-a925-4f12-be99-e81fb3ddf0f2-0', tool_calls=[{'name': 'get_human_feedback', 'args': {'query': 'what is the weather in mumbai'}, 'id': 'call_x5IGYrgyUzAeibariqhQL6SA', 'type': 'tool_call'}], usage_metadata={'input_tokens': 183, 'output_tokens': 23, 'total_tokens': 206, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})],
#  '__interrupt__': [Interrupt(value={'type': 'human_feedback', 'query': 'what is the weather in mumbai'}, id='ce3969efae3872ffd8fa3895dc916bb3')]}

# %%
response = supervisor_agent.invoke(
    Command(resume="We do not support this query")
    , config=config)
response
# Out:
# OPIK: You are attempting to log data into a nested span under the project name "customer-support". However, the project name "Default Project" from parent span will be used instead.
# {'messages': [HumanMessage(content='what is the weather in mumbai', additional_kwargs={}, response_metadata={}, id='26864288-d5bc-44d4-8fd6-f810be479535'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 183, 'total_tokens': 206, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_3dcd5944f5', 'id': 'chatcmpl-CjflxVVfvG7jwW2PPM7mdi4AxdQQY', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'tool_calls', 'logprobs': None, 'content_filter_results': {}}, id='lc_run--15829850-a925-4f12-be99-e81fb3ddf0f2-0', tool_calls=[{'name': 'get_human_feedback', 'args': {'query': 'what is the weather in mumbai'}, 'id': 'call_x5IGYrgyUzAeibariqhQL6SA', 'type': 'tool_call'}], usage_metadata={'input_tokens': 183, 'output_tokens': 23, 'total_tokens': 206, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content='We do not support this query', name='get_human_feedback', id='4cf215b9-3cb0-4d69-9e37-e80722757631', tool_call_id='call_x5IGYrgyUzAeibariqhQL6SA'),
#   AIMessage(content='I am currently unable to provide weather information. You can check the weather in Mumbai using a weather website or app like Weather.com or AccuWeather. Is there anything else I can assist you with?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 221, 'total_tokens': 263, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_3dcd5944f5', 'id': 'chatcmpl-CjfnQPsRuVZNF4x4079KUyrhZdg4c', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--37226ece-8661-48fb-9684-88e88b9887b1-0', usage_metadata={'input_tokens': 221, 'output_tokens': 42, 'total_tokens': 263, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
user ui -> query
query -> backend server
backend server -> agent
backend server -> human agent server
human agent server -> backend server
backend server -> agent (human agent feedback)
backend server -> user ui (final response)
