# %%
pdf_path = '../SmartScriblle.pdf'

# %% [markdown]
# ## Document Parsing Using PyPdf

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters  import MarkdownHeaderTextSplitter
import pymupdf4llm

# Load and parse the PDF with markdown structure
md_text = pymupdf4llm.to_markdown(pdf_path)

# Split by markdown headers
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
]

markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
md_header_splits = markdown_splitter.split_text(md_text)

# Display the parsed sections
for i, section in enumerate(md_header_splits):
    print(f"Section {i}:")
    print(f"Content: {section.page_content[:200]}...")
    print(f"Metadata: {section.metadata}")
    print("-" * 50)
# Out:
# Consider using the pymupdf_layout package for a greatly improved page layout analysis.
# Section 0:
# Content: **"The Renaissance of Writing in the Age of Artificial Intelligence"**...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook'}
# --------------------------------------------------
# Section 1:
# Content: In an era dominated by glowing screens, constant notifications, and digital noise, the act of deep thinking has become a
# lost art. While digital tools offer speed and connectivity, they often lack t...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 1: Executive Summary & Philosophy', 'Header 3': 'The Vision'}
# --------------------------------------------------
# Section 2:
# Content: 1. **Focus:** A distraction-free environment using E-Ink technology.
# 2. **Intelligence:** On-board and Cloud-based AI that understands, organizes, and expands upon user input.
# 3. **Integration:** ...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 1: Executive Summary & Philosophy', 'Header 3': 'Core Value Proposition'}
# --------------------------------------------------
# Section 3:
# Content: The heart of the SmartScribble is its proprietary **CanvasInk™ Display** . Unlike LCD or OLED screens that blast light into
# your eyes, our high-resolution E-Ink panel reflects ambient light, just li...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 2: Hardware Engineering & Design', 'Header 3': 'The Display: Paper Perfected'}
# --------------------------------------------------
# Section 4:
# Content: Included with every device is the **Scribble Pen Pro** . It requires no pairing and charges magnetically when attached to the
# side of the notebook.
# **Pressure Sensitivity:** With 4,096 levels of p...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 2: Hardware Engineering & Design', 'Header 3': 'The Smart Stylus'}
# --------------------------------------------------
# Section 5:
# Content: **Chassis:** Machined from an aerospace-grade aluminum alloy for rigidity and lightness.
# **Thickness:** At just \(5.8mm\), it is thinner than a typical smartphone and slides easily into any folio or...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 2: Hardware Engineering & Design', 'Header 3': 'Build Quality & Form Factor'}
# --------------------------------------------------
# Section 6:
# Content: The "Smart" in SmartScribble is driven by our dual-layer AI architecture: **Local Core** (for privacy and speed) and **Cloud**
# **Nexus** (for power)....
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 3: The AI Engine (Software)'}
# --------------------------------------------------
# Section 7:
# Content: SmartScribble doesn't just see pixels; it sees language.
# **Real-Time Conversion:** As you write, the background processor converts handwriting to machine-encoded text.
# This allows you to tap a but...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 3: The AI Engine (Software)', 'Header 3': '1. Intelligent Handwriting Recognition (OCR)'}
# --------------------------------------------------
# Section 8:
# Content: This is the flagship feature that separates SmartScribble from every other E-Ink tablet on the market. By connecting to
# the **Cloud Nexus**, users can interact with a Generative AI specifically tune...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 3: The AI Engine (Software)', 'Header 3': '2. AI-Powered Idea Expansion (The Muse)'}
# --------------------------------------------------
# Section 9:
# Content: **Auto-Tagging:** The AI analyzes the content of your notes. If you write about "Q4 Revenue," the note is
# automatically tagged with #Finance and #Q4.
# **Global Search:** You can search for a handwr...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 3: The AI Engine (Software)', 'Header 3': '3. Smart Organization & Search'}
# --------------------------------------------------
# Section 10:
# Content: The SmartScribble fits into your existing life; it doesn't force you to change it....
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 4: Workflow & Ecosystem Integration'}
# --------------------------------------------------
# Section 11:
# Content: The device connects via Wi-Fi (\(802.11ac\)) to sync data. We support bi-directional sync with major platforms:
# **Google Drive:** Notes saved as PDFs or editable Google Docs.
# **OneNote:** Direct i...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 4: Workflow & Ecosystem Integration', 'Header 3': 'Cloud Synchronization'}
# --------------------------------------------------
# Section 12:
# Content: **Live View:** Present via the app. Draw on the SmartScribble, and have it appear in real-time on a computer screen
# - perfect for remote teaching or boardroom whiteboarding.
# **File Management:** O...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 4: Workflow & Ecosystem Integration', 'Header 3': 'The Companion App (iOS / Android / Desktop)'}
# --------------------------------------------------
# Section 13:
# Content: We understand that inspiration strikes anywhere—on a plane, in a park, or in a tunnel.
# **Local Storage:** With \(64GB\) of internal storage, the device can hold roughly 100,000 pages of notes.
# **Q...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 4: Workflow & Ecosystem Integration', 'Header 3': 'Offline Capabilities'}
# --------------------------------------------------
# Section 14:
# Content: _Scenario:_ A VP is in back-to-back meetings. _Usage:_ They use the **Meeting Template** (Date, Attendees, Agenda pre
# filled). They jot down action items. At the end of the day, they use the AI to "...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 5: Use Case Scenarios', 'Header 3': 'The Corporate Executive'}
# --------------------------------------------------
# Section 15:
# Content: _Scenario:_ A medical student attending a complex anatomy lecture. _Usage:_ They sketch a diagram of the heart. They
# label the valves. Later, they use the "AI Expand" feature on the label "Mitral Va...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 5: Use Case Scenarios', 'Header 3': 'The University Student'}
# --------------------------------------------------
# Section 16:
# Content: _Scenario:_ A novelist working on a plot outline. _Usage:_ They use the **Storyboard Template** . They write out character arcs.
# They get stuck on a plot hole. They query the AI: "Suggest plot twist...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 5: Use Case Scenarios', 'Header 3': 'The Creative Writer'}
# --------------------------------------------------
# Section 17:
# Content: _Scenario:_ System architecture planning. _Usage:_ Using the **Grid Template**, the engineer draws a system topology. They
# use the stylus to draw perfect straight lines and circles (assisted by geom...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 5: Use Case Scenarios', 'Header 3': 'The Developer/Engineer'}
# --------------------------------------------------
# Section 18:
# Content: **Category** **Specification**
# **Display** 10.3-inch CanvasInk™ E-Ink Display (Monochrome)
# **Resolution** \(1872 \times 1404\) (227 DPI)
# **Processor** Quad-Core 1.8GHz ARM Cortex Processor
# **Stora...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 6: Technical Specifications'}
# --------------------------------------------------
# Section 19:
# Content: The SmartScribble is not limited to blank pages. It includes a library of over 50 dynamic templates, including:
# **Productivity:** Daily Planner, Weekly Schedule, Eisenhower Matrix, Kanban Board.
# *...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 7: Templates & Customization'}
# --------------------------------------------------
# Section 20:
# Content: **Q: How accurate is the handwriting recognition on messy writing?** A: The engine is rated at 95% accuracy for
# standard neat handwriting. For "messy" or cursive writing, the AI utilizes contextual ...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 8: Frequently Asked Questions (FAQ)', 'Header 3': 'Functionality & Usage'}
# --------------------------------------------------
# Section 21:
# Content: **Q: How durable is the stylus tips?** A: The stylus tips are made of a durable felt-composite to mimic the feel of a pencil.
# A standard tip lasts 3–6 months depending on writing pressure. The packa...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 8: Frequently Asked Questions (FAQ)', 'Header 3': 'Hardware & Accessories'}
# --------------------------------------------------
# Section 22:
# Content: **Q: Is there a monthly fee for the AI features?** A: The basic handwriting recognition and cloud sync are free forever.
# The **"Advanced AI Expansion"** (generative brainstorming) is free for the fi...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 8: Frequently Asked Questions (FAQ)', 'Header 3': 'Software & Subscription'}
# --------------------------------------------------
# Section 23:
# Content: **Q: What happens if I break the screen?** A: E-Ink screens are delicate. We offer a standard 1-year manufacturer
# warranty covering defects. We highly recommend purchasing our "ScribbleCare+" protec...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': 'Section 8: Frequently Asked Questions (FAQ)', 'Header 3': 'Support & Warranty'}
# --------------------------------------------------
# Section 24:
# Content: 1. **SmartScribble AI Notebook** (Graphite Grey)
# 2. **Scribble Pen Pro** (Magnetic Stylus)
# 3. **Replacement Nibs** (x5) and Nib Removal Tool
# 4. **USB-C to USB-A Braided Charging Cable** (1.5m)  ...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': "Section 9: What's in the Box?"}
# --------------------------------------------------
# Section 25:
# Content: The SmartScribble is more than a gadget; it is a commitment to your own thoughts. By clearing away the clutter of the
# modern web and focusing on the purity of the handwritten word—amplified by the i...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': "Section 9: What's in the Box?", 'Header 3': '**Closing Statement**'}
# --------------------------------------------------
# Section 26:
# Content: 1. Draft a specific **email marketing campaign** targeting university students for this product?
# 2. Create a **User Manual** section regarding how to use the specific "AI Expand" gestures?
# 3. Gene...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook', 'Header 2': "Section 9: What's in the Box?", 'Header 3': 'Would you like me to...'}
# --------------------------------------------------

# %%
print(md_text)
# Out:
# # The SmartScribble AI Notebook
#
# **"The Renaissance of Writing in the Age of Artificial Intelligence"**
#
# ## Section 1: Executive Summary & Philosophy
#
# ### The Vision
#
#
# In an era dominated by glowing screens, constant notifications, and digital noise, the act of deep thinking has become a
#
#
# lost art. While digital tools offer speed and connectivity, they often lack the cognitive benefits of handwriting—the tactile
#
#
# connection that helps the brain synthesize information and retain memory. Conversely, traditional paper notebooks, while
#
#
# conducive to focus, are disconnected 'data islands'—unsearchable, shareable only by scanning, and vulnerable to loss.
#
#
# Enter the **SmartScribble AI Notebook** .
#
#
# SmartScribble acts as the bridge between the analog and digital worlds. It is not a tablet trying to be a computer; it is a
#
#
# notebook supercharged with the limitless potential of Artificial Intelligence. It preserves the friction and flow of pen on
#
#
# paper while seamlessly integrating the content into the user's digital workflow. It is designed for the thinkers, the creators,
#
#
# the students, and the leaders who refuse to compromise between the joy of writing and the efficiency of technology.
#
# ### Core Value Proposition
#
#
# 1. **Focus:** A distraction-free environment using E-Ink technology.
#
#
# 2. **Intelligence:** On-board and Cloud-based AI that understands, organizes, and expands upon user input.
#
#
# 3. **Integration:** An agnostic ecosystem that plays well with the tools you already use (Google, Microsoft, Evernote).
#
#
# 4. **Longevity:** Hardware built to last, with battery life that outlasts the longest workdays.
#
# ## Section 2: Hardware Engineering & Design
#
# ### The Display: Paper Perfected
#
#
# The heart of the SmartScribble is its proprietary **CanvasInk™ Display** . Unlike LCD or OLED screens that blast light into
#
#
# your eyes, our high-resolution E-Ink panel reflects ambient light, just like real paper.
#
#
# **Glare-Free:** Perfect visibility in bright sunlight or studio lighting.
#
#
# **Texture:** The screen surface is treated with a micro-etched matte finish. This provides the necessary "tooth" or
#
#
# friction against the stylus tip, eliminating the slippery "glassy" feel of standard tablets.
#
#
# **Zero-Lag Refresh:** Powered by a dedicated display controller, the latency is reduced to \(<20ms\), rendering ink
#
#
# almost instantly as the stylus moves.
#
# ### The Smart Stylus
#
#
# Included with every device is the **Scribble Pen Pro** . It requires no pairing and charges magnetically when attached to the
#
#
# side of the notebook.
#
#
# **Pressure Sensitivity:** With 4,096 levels of pressure sensitivity, the pen captures the nuance of your hand. Press
#
#
# hard for bold headers, or lightly for delicate shading in sketches.
#
#
# **Tilt Support:** The pen recognizes tilt, allowing artists to shade as they would with a graphite pencil.
#
#
# **Ergonomics:** Weighted to feel like a premium fountain pen, not a hollow plastic stick.
#
# ### Build Quality & Form Factor
#
#
# **Chassis:** Machined from an aerospace-grade aluminum alloy for rigidity and lightness.
#
#
# **Thickness:** At just \(5.8mm\), it is thinner than a typical smartphone and slides easily into any folio or bag.
#
#
# **Weight:** Weighing under \(400g\), it is comfortable to hold in one hand for extended reading or reviewing
#
#
# sessions.
#
# ## Section 3: The AI Engine (Software)
#
#
# The "Smart" in SmartScribble is driven by our dual-layer AI architecture: **Local Core** (for privacy and speed) and **Cloud**
#
#
# **Nexus** (for power).
#
# ### 1. Intelligent Handwriting Recognition (OCR)
#
#
# SmartScribble doesn't just see pixels; it sees language.
#
#
# **Real-Time Conversion:** As you write, the background processor converts handwriting to machine-encoded text.
#
#
# This allows you to tap a button and instantly email your handwritten meeting notes as a typed executive summary.
#
#
# **Adaptive Learning:** The algorithm utilizes a localized neural network that learns your specific quirks—how you
#
#
# cross your 't's or loop your 'y's. The more you use it, the closer the accuracy gets to \(100\%\).
#
#
# **Multi-Language Support:** Full OCR support is currently active for English, Spanish, French, German, Chinese
#
#
# (Simplified/Traditional), Japanese, and Korean, with mixed-language recognition capabilities.
#
# ### 2. AI-Powered Idea Expansion (The Muse)
#
#
# This is the flagship feature that separates SmartScribble from every other E-Ink tablet on the market. By connecting to
#
#
# the **Cloud Nexus**, users can interact with a Generative AI specifically tuned for ideation.
#
#
# **The "Expand" Command:** Circle a keyword (e.g., "Marketing Strategy") and select "Expand." The AI will
#
#
# generate a sub-list of bullet points (e.g., "Social Media Channels," "Budget Allocation," "Influencer Outreach")
#
#
# directly onto the page in a distinct digital font.
#
#
# **Writer's Block Breaker:** Stuck on a sentence? Draw a question mark in the margin, and the AI will offer context
#
# aware prompts or continuations based on the previous paragraphs.
#
#
# **Summarization:** Highlight several pages of notes and ask the AI to "Generate Summary." It will create a concise
#
#
# bulleted list of key takeaways on a new page.
#
# ### 3. Smart Organization & Search
#
#
# **Auto-Tagging:** The AI analyzes the content of your notes. If you write about "Q4 Revenue," the note is
#
#
# automatically tagged with #Finance and #Q4.
#
#
# **Global Search:** You can search for a handwritten phrase (e.g., "Project Alpha") across thousands of pages of
#
#
# notes, and the device will locate every instance in seconds.
#
# ## Section 4: Workflow & Ecosystem Integration
#
#
# The SmartScribble fits into your existing life; it doesn't force you to change it.
#
# ### Cloud Synchronization
#
#
# The device connects via Wi-Fi (\(802.11ac\)) to sync data. We support bi-directional sync with major platforms:
#
#
# **Google Drive:** Notes saved as PDFs or editable Google Docs.
#
#
# **OneNote:** Direct integration into OneNote Notebooks.
#
#
# **Evernote:** Syncs to specific notebooks with tags preserved.
#
#
# **Dropbox / OneDrive:** Auto-backup of raw vector files and PDFs.
#
# ### The Companion App (iOS / Android / Desktop)
#
#
# **Live View:** Present via the app. Draw on the SmartScribble, and have it appear in real-time on a computer screen
#
#
#  - perfect for remote teaching or boardroom whiteboarding.
#
#
# **File Management:** Organize folders, rename files, and adjust AI settings from your phone.
#
# ### Offline Capabilities
#
#
# We understand that inspiration strikes anywhere—on a plane, in a park, or in a tunnel.
#
#
# **Local Storage:** With \(64GB\) of internal storage, the device can hold roughly 100,000 pages of notes.
#
#
# **Queue Syncing:** All changes made offline are cached and automatically uploaded the moment a connection is
#
#
# re-established.
#
#
# ## Section 5: Use Case Scenarios
#
# ### The Corporate Executive
#
# _Scenario:_ A VP is in back-to-back meetings. _Usage:_ They use the **Meeting Template** (Date, Attendees, Agenda pre
#
# filled). They jot down action items. At the end of the day, they use the AI to "Extract Action Items," which generates a
#
#
# checklist. They tap "Send to Email," and the text is sent to their assistant.
#
# ### The University Student
#
#
# _Scenario:_ A medical student attending a complex anatomy lecture. _Usage:_ They sketch a diagram of the heart. They
#
#
# label the valves. Later, they use the "AI Expand" feature on the label "Mitral Valve," and the device inserts a small text
#
#
# box definition next to their drawing. They search "Aorta" three months later to find this specific lecture.
#
# ### The Creative Writer
#
#
# _Scenario:_ A novelist working on a plot outline. _Usage:_ They use the **Storyboard Template** . They write out character arcs.
#
#
# They get stuck on a plot hole. They query the AI: "Suggest plot twist involving the antagonist." The AI provides three
#
#
#                - ptions. The writer chooses one and continues handwriting.
#
# ### The Developer/Engineer
#
#
# _Scenario:_ System architecture planning. _Usage:_ Using the **Grid Template**, the engineer draws a system topology. They
#
#
# use the stylus to draw perfect straight lines and circles (assisted by geometric auto-correct). They export the diagram as
#
#
# an SVG file to import into technical documentation.
#
# ## Section 6: Technical Specifications
#
#
# **Category** **Specification**
# **Display** 10.3-inch CanvasInk™ E-Ink Display (Monochrome)
# **Resolution** \(1872 \times 1404\) (227 DPI)
#
# **Processor** Quad-Core 1.8GHz ARM Cortex Processor
#
# **Storage** \(64GB\) Internal Storage (Non-expandable)
# **RAM** \(4GB\) LPDDR4X
# **Connectivity** Wi-Fi (\(2.4GHz + 5GHz\)), Bluetooth 5.0, USB-C
# **Battery** \(3000mAh\) Li-Ion (Up to 2 weeks standby, 10 hours active writing)
# **Stylus** Wacom EMR Technology (Battery-free), 4096 Pressure Levels
# **Dimensions** \(230mm \times 190mm \times 5.8mm\)
# **Weight** \(395g\)
# **OS** SmartOS (Based on Linux Kernel)
#
# **File Formats** PDF, EPUB, TXT, PNG, SVG
#
#
# ## Section 7: Templates & Customization
#
# The SmartScribble is not limited to blank pages. It includes a library of over 50 dynamic templates, including:
#
#
# **Productivity:** Daily Planner, Weekly Schedule, Eisenhower Matrix, Kanban Board.
#
#
# **Education:** Ruled (College/Wide), Cornell Notes, Sheet Music, Chemistry Hex Grid.
#
#
# **Business:** Meeting Minutes, SWOT Analysis, Project Timeline.
#
#
# **Creative:** Storyboard (16:9), Comic Strip Layouts, Isometric Grid, Perspective Dot Grid.
#
#
# _Users can also upload custom PDF templates (e.g., corporate forms) to use as backgrounds._
#
# ## Section 8: Frequently Asked Questions (FAQ)
#
# ### Functionality & Usage
#
#
# **Q: How accurate is the handwriting recognition on messy writing?** A: The engine is rated at 95% accuracy for
#
#
# standard neat handwriting. For "messy" or cursive writing, the AI utilizes contextual prediction. If you write a messy word
#
#
# in a sentence about "finance," it is more likely to interpret a squiggle as "budget" rather than "badger." It improves
#
#
# significantly after 1-2 weeks of usage as it builds a profile of your style.
#
#
# **Q: Can I edit the text after it has been converted?** A: Yes. Once converted, the text block can be edited using an on
#
# screen keyboard, or you can export it to a computer for final polishing.
#
#
# **Q: Does the device emit blue light?** A: No. The E-Ink display is front-lit, not back-lit, meaning light is cast onto the
#
#
# page, not into your eyes. You can adjust the "warmth" of the light (from cool white to amber) to match your circadian
#
#
# rhythm.
#
# ### Hardware & Accessories
#
#
# **Q: How durable is the stylus tips?** A: The stylus tips are made of a durable felt-composite to mimic the feel of a pencil.
#
#
# A standard tip lasts 3–6 months depending on writing pressure. The package includes 5 replacement tips and a removal
#
#
# tool.
#
#
# **Q: Is the device water-resistant?** A: The SmartScribble is splash-resistant (IP52 rated), meaning it can handle light rain
#
#
#                    - r a minor spill, but it should not be submerged.
#
# ### Software & Subscription
#
#
# **Q: Is there a monthly fee for the AI features?** A: The basic handwriting recognition and cloud sync are free forever.
#
#
# The **"Advanced AI Expansion"** (generative brainstorming) is free for the first year. After that, it is a strictly optional
#
#
# subscription of $4.99/month to cover cloud computing costs.
#
#
# **Q: How secure is my data?** A: Security is paramount. All notes are encrypted at rest (AES-256) and in transit (TLS 1.3).
#
#
# Users can also password-protect specific folders or the entire device.
#
# ### Support & Warranty
#
#
# **Q: What happens if I break the screen?** A: E-Ink screens are delicate. We offer a standard 1-year manufacturer
#
#
# warranty covering defects. We highly recommend purchasing our "ScribbleCare+" protection plan ($49), which covers
#
#
# accidental damage, including screen drops, for two years.
#
#
# **Q: What is the return policy?** A: We are confident you will love the SmartScribble. If you are not satisfied, you may
#
#
# return the device in its original packaging within 30 days of receipt for a full refund, minus return shipping costs.
#
# ## Section 9: What's in the Box?
#
#
# 1. **SmartScribble AI Notebook** (Graphite Grey)
#
#
# 2. **Scribble Pen Pro** (Magnetic Stylus)
#
#
# 3. **Replacement Nibs** (x5) and Nib Removal Tool
#
#
# 4. **USB-C to USB-A Braided Charging Cable** (1.5m)
#
#
# 5. **Quick Start Guide**
#
#
# 6. **Microfiber Cleaning Cloth**
#
# ### **Closing Statement**
#
#
# The SmartScribble is more than a gadget; it is a commitment to your own thoughts. By clearing away the clutter of the
#
#
# modern web and focusing on the purity of the handwritten word—amplified by the intelligence of AI—we enable you to
#
#
# create your best work.
#
#
# **SmartScribble. Your Ideas, Amplified.**
#
# ### Would you like me to...
#
#
# 1. Draft a specific **email marketing campaign** targeting university students for this product?
#
#
# 2. Create a **User Manual** section regarding how to use the specific "AI Expand" gestures?
#
#
# 3. Generate a **comparison table** comparing SmartScribble to competitors like reMarkable or Kindle Scribe?

# %% [markdown]
# ## Document Parsing Using Azure Embeddings

# %%
from langchain_community.document_loaders import AzureAIDocumentIntelligenceLoader

file_path = pdf_path 
endpoint = "<endpoint>"
key = "<key>"

loader = AzureAIDocumentIntelligenceLoader(
    api_endpoint=endpoint, api_key=key, file_path=file_path, api_model="prebuilt-layout"
)

documents = loader.load()

# %%
# Split by markdown headers
headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
    ("###", "Header 3"),
]

markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
md_header_splits = markdown_splitter.split_text(documents[0].metadata['content'])

# Display the parsed sections
for i, section in enumerate(md_header_splits):
    print(f"Section {i}:")
    print(f"Content: {section.page_content[:200]}...")
    print(f"Metadata: {section.metadata}")
    print("-" * 50)
# Out:
# Section 0:
# Content: "The Renaissance of Writing in the Age of Artificial Intelligence"...
# Metadata: {'Header 1': 'The SmartScribble AI Notebook'}
# --------------------------------------------------
# Section 1:
# Content: In an era dominated by glowing screens, constant notifications, and digital noise, the act of deep thinking has become a
# lost art. While digital tools offer speed and connectivity, they often lack the...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'The Vision'}
# --------------------------------------------------
# Section 2:
# Content: 1\. Focus: A distraction-free environment using E-Ink technology.
# 2\. Intelligence: On-board and Cloud-based AI that understands, organizes, and expands upon user input.
# 3\. Integration: An agnost...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Core Value Proposition'}
# --------------------------------------------------
# Section 3:
# Content: The Display: Paper Perfected
# The heart of the SmartScribble is its proprietary CanvasInk™ Display. Unlike LCD or OLED screens that blast light into
# your eyes, our high-resolution E-Ink panel reflect...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Section 2: Hardware Engineering & Design'}
# --------------------------------------------------
# Section 4:
# Content: Included with every device is the Scribble Pen Pro. It requires no pairing and charges magnetically when attached to the
# side of the notebook.
# · Pressure Sensitivity: With 4,096 levels of pressure s...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'The Smart Stylus'}
# --------------------------------------------------
# Section 5:
# Content: · Chassis: Machined from an aerospace-grade aluminum alloy for rigidity and lightness.
# · Thickness: At just \\(5.8mml), it is thinner than a typical smartphone and slides easily into any folio or ba...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Build Quality & Form Factor'}
# --------------------------------------------------
# Section 6:
# Content: The "Smart" in SmartScribble is driven by our dual-layer AI architecture: Local Core (for privacy and speed) and Cloud
# Nexus (for power)....
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Section 3: The AI Engine (Software)'}
# --------------------------------------------------
# Section 7:
# Content: SmartScribble doesn't just see pixels; it sees language.
# · Real-Time Conversion: As you write, the background processor converts handwriting to machine-encoded text.
# This allows you to tap a button ...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': '1. Intelligent Handwriting Recognition (OCR)'}
# --------------------------------------------------
# Section 8:
# Content: This is the flagship feature that separates SmartScribble from every other E-Ink tablet on the market. By connecting to
# the Cloud Nexus, users can interact with a Generative AI specifically tuned for ...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': '2. AI-Powered Idea Expansion (The Muse)'}
# --------------------------------------------------
# Section 9:
# Content: . Auto-Tagging: The Al analyzes the content of your notes. If you write about "Q4 Revenue," the note is
# automatically tagged with #Finance and #Q4.
# · Global Search: You can search for a handwritten ...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': '3. Smart Organization & Search'}
# --------------------------------------------------
# Section 10:
# Content: The SmartScribble fits into your existing life; it doesn't force you to change it....
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Section 4: Workflow & Ecosystem Integration'}
# --------------------------------------------------
# Section 11:
# Content: The device connects via Wi-Fi (\\(802.11acl)) to sync data. We support bi-directional sync with major platforms:
# · Google Drive: Notes saved as PDFs or editable Google Docs.
# · OneNote: Direct inte...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Section 4: Workflow & Ecosystem Integration', 'Header 3': 'Cloud Synchronization'}
# --------------------------------------------------
# Section 12:
# Content: . Live View: Present via the app. Draw on the SmartScribble, and have it appear in real-time on a computer screen
# -perfect for remote teaching or boardroom whiteboarding.
# · File Management: Organize...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Section 4: Workflow & Ecosystem Integration', 'Header 3': 'The Companion App (iOS / Android / Desktop)'}
# --------------------------------------------------
# Section 13:
# Content: We understand that inspiration strikes anywhere-on a plane, in a park, or in a tunnel.
# · Local Storage: With \\(64GBI) of internal storage, the device can hold roughly 100,000 pages of notes.
# · Qu...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Offline Capabilities'}
# --------------------------------------------------
# Section 14:
# Content: Scenario: A VP is in back-to-back meetings. Usage: They use the Meeting Template (Date, Attendees, Agenda pre-
# filled). They jot down action items. At the end of the day, they use the AI to "Extract A...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Section 5: Use Case Scenarios', 'Header 3': 'The Corporate Executive'}
# --------------------------------------------------
# Section 15:
# Content: Scenario: A medical student attending a complex anatomy lecture. Usage: They sketch a diagram of the heart. They
# label the valves. Later, they use the "AI Expand" feature on the label "Mitral Valve," ...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Section 5: Use Case Scenarios', 'Header 3': 'The University Student'}
# --------------------------------------------------
# Section 16:
# Content: Scenario: A novelist working on a plot outline. Usage: They use the Storyboard Template. They write out character arcs.
# They get stuck on a plot hole. They query the AI: "Suggest plot twist involving ...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Section 5: Use Case Scenarios', 'Header 3': 'The Creative Writer'}
# --------------------------------------------------
# Section 17:
# Content: Scenario: System architecture planning. Usage: Using the Grid Template, the engineer draws a system topology. They
# use the stylus to draw perfect straight lines and circles (assisted by geometric auto...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Section 5: Use Case Scenarios', 'Header 3': 'The Developer/Engineer'}
# --------------------------------------------------
# Section 18:
# Content: <table>
# <tr>
# <td>Category</td>
# <td>Specification</td>
# </tr>
# <tr>
# <td>Display</td>
# <td>10.3-inch CanvasInk™ E-Ink Display (Monochrome)</td>
# </tr>
# <tr>
# <td>Resolution</td>
# <td>(1872 \times 14041) (227 D...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Section 5: Use Case Scenarios', 'Header 3': 'Section 6: Technical Specifications'}
# --------------------------------------------------
# Section 19:
# Content: The SmartScribble is not limited to blank pages. It includes a library of over 50 dynamic templates, including:
# · Productivity: Daily Planner, Weekly Schedule, Eisenhower Matrix, Kanban Board.
# · E...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Section 5: Use Case Scenarios', 'Header 3': 'Section 7: Templates & Customization'}
# --------------------------------------------------
# Section 20:
# Content: #### Functionality & Usage
# Q: How accurate is the handwriting recognition on messy writing? A: The engine is rated at 95% accuracy for
# standard neat handwriting. For "messy" or cursive writing, the ...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Section 5: Use Case Scenarios', 'Header 3': 'Section 8: Frequently Asked Questions (FAQ)'}
# --------------------------------------------------
# Section 21:
# Content: 1\. Draft a specific email marketing campaign targeting university students for this product?
# 2\. Create a User Manual section regarding how to use the specific "AI Expand" gestures?
# 3\. Generate ...
# Metadata: {'Header 1': 'Section 1: Executive Summary & Philosophy', 'Header 2': 'Section 5: Use Case Scenarios', 'Header 3': 'Would you like me to ...'}
# --------------------------------------------------

# %%
print(documents[0].metadata['content'])
# Out:
# # The SmartScribble AI Notebook
#
# "The Renaissance of Writing in the Age of Artificial Intelligence"
#
#
# # Section 1: Executive Summary & Philosophy
#
#
# ## The Vision
#
# In an era dominated by glowing screens, constant notifications, and digital noise, the act of deep thinking has become a
# lost art. While digital tools offer speed and connectivity, they often lack the cognitive benefits of handwriting-the tactile
# connection that helps the brain synthesize information and retain memory. Conversely, traditional paper notebooks, while
# conducive to focus, are disconnected 'data islands'-unsearchable, shareable only by scanning, and vulnerable to loss.
#
# Enter the SmartScribble AI Notebook.
#
# SmartScribble acts as the bridge between the analog and digital worlds. It is not a tablet trying to be a computer; it is a
# notebook supercharged with the limitless potential of Artificial Intelligence. It preserves the friction and flow of pen on
# paper while seamlessly integrating the content into the user's digital workflow. It is designed for the thinkers, the creators,
# the students, and the leaders who refuse to compromise between the joy of writing and the efficiency of technology.
#
#
# ## Core Value Proposition
#
# 1\. Focus: A distraction-free environment using E-Ink technology.
#
# 2\. Intelligence: On-board and Cloud-based AI that understands, organizes, and expands upon user input.
#
# 3\. Integration: An agnostic ecosystem that plays well with the tools you already use (Google, Microsoft, Evernote).
#
# 4\. Longevity: Hardware built to last, with battery life that outlasts the longest workdays.
#
#
# ## Section 2: Hardware Engineering & Design
#
# The Display: Paper Perfected
#
# The heart of the SmartScribble is its proprietary CanvasInk™ Display. Unlike LCD or OLED screens that blast light into
# your eyes, our high-resolution E-Ink panel reflects ambient light, just like real paper.
#
# <!-- PageBreak -->
#
# · Glare-Free: Perfect visibility in bright sunlight or studio lighting.
#
# · Texture: The screen surface is treated with a micro-etched matte finish. This provides the necessary "tooth" or
# friction against the stylus tip, eliminating the slippery "glassy" feel of standard tablets.
#
# · Zero-Lag Refresh: Powered by a dedicated display controller, the latency is reduced to \\(<20msl), rendering ink
# almost instantly as the stylus moves.
#
#
# ## The Smart Stylus
#
# Included with every device is the Scribble Pen Pro. It requires no pairing and charges magnetically when attached to the
# side of the notebook.
#
# · Pressure Sensitivity: With 4,096 levels of pressure sensitivity, the pen captures the nuance of your hand. Press
# hard for bold headers, or lightly for delicate shading in sketches.
#
# · Tilt Support: The pen recognizes tilt, allowing artists to shade as they would with a graphite pencil.
#
# · Ergonomics: Weighted to feel like a premium fountain pen, not a hollow plastic stick.
#
#
# ## Build Quality & Form Factor
#
# · Chassis: Machined from an aerospace-grade aluminum alloy for rigidity and lightness.
#
# · Thickness: At just \\(5.8mml), it is thinner than a typical smartphone and slides easily into any folio or bag.
#
# · Weight: Weighing under \\(400gl), it is comfortable to hold in one hand for extended reading or reviewing
# sessions.
#
#
# ## Section 3: The AI Engine (Software)
#
# The "Smart" in SmartScribble is driven by our dual-layer AI architecture: Local Core (for privacy and speed) and Cloud
# Nexus (for power).
#
#
# ## 1. Intelligent Handwriting Recognition (OCR)
#
# SmartScribble doesn't just see pixels; it sees language.
#
# · Real-Time Conversion: As you write, the background processor converts handwriting to machine-encoded text.
# This allows you to tap a button and instantly email your handwritten meeting notes as a typed executive summary.
#
# · Adaptive Learning: The algorithm utilizes a localized neural network that learns your specific quirks-how you
# cross your 't's or loop your 'y's. The more you use it, the closer the accuracy gets to \\(1001%l).
#
# · Multi-Language Support: Full OCR support is currently active for English, Spanish, French, German, Chinese
# (Simplified/Traditional), Japanese, and Korean, with mixed-language recognition capabilities.
#
#
# ## 2. AI-Powered Idea Expansion (The Muse)
#
# This is the flagship feature that separates SmartScribble from every other E-Ink tablet on the market. By connecting to
# the Cloud Nexus, users can interact with a Generative AI specifically tuned for ideation.
#
# <!-- PageBreak -->
#
# · The "Expand" Command: Circle a keyword (e.g., "Marketing Strategy") and select "Expand." The Al will
# generate a sub-list of bullet points (e.g., "Social Media Channels," "Budget Allocation," "Influencer Outreach")
# directly onto the page in a distinct digital font.
#
# · Writer's Block Breaker: Stuck on a sentence? Draw a question mark in the margin, and the Al will offer context-
# aware prompts or continuations based on the previous paragraphs.
#
# · Summarization: Highlight several pages of notes and ask the Al to "Generate Summary." It will create a concise
# bulleted list of key takeaways on a new page.
#
#
# ## 3. Smart Organization & Search
#
# . Auto-Tagging: The Al analyzes the content of your notes. If you write about "Q4 Revenue," the note is
# automatically tagged with #Finance and #Q4.
#
# · Global Search: You can search for a handwritten phrase (e.g., "Project Alpha") across thousands of pages of
# notes, and the device will locate every instance in seconds.
#
#
# ## Section 4: Workflow & Ecosystem Integration
#
# The SmartScribble fits into your existing life; it doesn't force you to change it.
#
#
# ### Cloud Synchronization
#
# The device connects via Wi-Fi (\\(802.11acl)) to sync data. We support bi-directional sync with major platforms:
#
# · Google Drive: Notes saved as PDFs or editable Google Docs.
#
# · OneNote: Direct integration into OneNote Notebooks.
#
# · Evernote: Syncs to specific notebooks with tags preserved.
#
# · Dropbox / OneDrive: Auto-backup of raw vector files and PDFs.
#
#
# ### The Companion App (iOS / Android / Desktop)
#
# . Live View: Present via the app. Draw on the SmartScribble, and have it appear in real-time on a computer screen
# -perfect for remote teaching or boardroom whiteboarding.
#
# · File Management: Organize folders, rename files, and adjust Al settings from your phone.
#
#
# ## Offline Capabilities
#
# We understand that inspiration strikes anywhere-on a plane, in a park, or in a tunnel.
#
# · Local Storage: With \\(64GBI) of internal storage, the device can hold roughly 100,000 pages of notes.
#
# · Queue Syncing: All changes made offline are cached and automatically uploaded the moment a connection is
# re-established.
#
# <!-- PageBreak -->
#
#
# ## Section 5: Use Case Scenarios
#
#
# ### The Corporate Executive
#
# Scenario: A VP is in back-to-back meetings. Usage: They use the Meeting Template (Date, Attendees, Agenda pre-
# filled). They jot down action items. At the end of the day, they use the AI to "Extract Action Items," which generates a
# checklist. They tap "Send to Email," and the text is sent to their assistant.
#
#
# ### The University Student
#
# Scenario: A medical student attending a complex anatomy lecture. Usage: They sketch a diagram of the heart. They
# label the valves. Later, they use the "AI Expand" feature on the label "Mitral Valve," and the device inserts a small text
# box definition next to their drawing. They search "Aorta" three months later to find this specific lecture.
#
#
# ### The Creative Writer
#
# Scenario: A novelist working on a plot outline. Usage: They use the Storyboard Template. They write out character arcs.
# They get stuck on a plot hole. They query the AI: "Suggest plot twist involving the antagonist." The AI provides three
# options. The writer chooses one and continues handwriting.
#
#
# ### The Developer/Engineer
#
# Scenario: System architecture planning. Usage: Using the Grid Template, the engineer draws a system topology. They
# use the stylus to draw perfect straight lines and circles (assisted by geometric auto-correct). They export the diagram as
# an SVG file to import into technical documentation.
#
#
# ### Section 6: Technical Specifications
#
#
# <table>
# <tr>
# <td>Category</td>
# <td>Specification</td>
# </tr>
# <tr>
# <td>Display</td>
# <td>10.3-inch CanvasInk™ E-Ink Display (Monochrome)</td>
# </tr>
# <tr>
# <td>Resolution</td>
# <td>(1872 \times 14041) (227 DPI)</td>
# </tr>
# <tr>
# <td>Processor</td>
# <td>Quad-Core 1.8GHz ARM Cortex Processor</td>
# </tr>
# <tr>
# <td>Storage</td>
# <td>(64GBI) Internal Storage (Non-expandable)</td>
# </tr>
# <tr>
# <td>RAM</td>
# <td>(4GBI) LPDDR4X</td>
# </tr>
# <tr>
# <td>Connectivity</td>
# <td>Wi-Fi (\(2.4GHz + 5GHzl)), Bluetooth 5.0, USB-C</td>
# </tr>
# <tr>
# <td>Battery</td>
# <td>\(3000mAhl) Li-lon (Up to 2 weeks standby, 10 hours active writing)</td>
# </tr>
# <tr>
# <td>Stylus</td>
# <td>Wacom EMR Technology (Battery-free), 4096 Pressure Levels</td>
# </tr>
# <tr>
# <td>Dimensions</td>
# <td>\(230mm Itimes 190mm \times 5.8mml)</td>
# </tr>
# <tr>
# <td>Weight</td>
# <td>(395g\)</td>
# </tr>
# <tr>
# <td>OS</td>
# <td>SmartOS (Based on Linux Kernel)</td>
# </tr>
# </table>
#
#
# File Formats PDF, EPUB, TXT, PNG, SVG
#
# <!-- PageBreak -->
#
#
# ### Section 7: Templates & Customization
#
# The SmartScribble is not limited to blank pages. It includes a library of over 50 dynamic templates, including:
#
# · Productivity: Daily Planner, Weekly Schedule, Eisenhower Matrix, Kanban Board.
#
# · Education: Ruled (College/Wide), Cornell Notes, Sheet Music, Chemistry Hex Grid.
#
# · Business: Meeting Minutes, SWOT Analysis, Project Timeline.
#
# · Creative: Storyboard (16:9), Comic Strip Layouts, Isometric Grid, Perspective Dot Grid.
#
# Users can also upload custom PDF templates (e.g., corporate forms) to use as backgrounds.
#
#
# ### Section 8: Frequently Asked Questions (FAQ)
#
#
# #### Functionality & Usage
#
# Q: How accurate is the handwriting recognition on messy writing? A: The engine is rated at 95% accuracy for
# standard neat handwriting. For "messy" or cursive writing, the AI utilizes contextual prediction. If you write a messy word
# in a sentence about "finance," it is more likely to interpret a squiggle as "budget" rather than "badger." It improves
# significantly after 1-2 weeks of usage as it builds a profile of your style.
#
# Q: Can I edit the text after it has been converted? A: Yes. Once converted, the text block can be edited using an on-
# screen keyboard, or you can export it to a computer for final polishing.
#
# Q: Does the device emit blue light? A: No. The E-Ink display is front-lit, not back-lit, meaning light is cast onto the
# page, not into your eyes. You can adjust the "warmth" of the light (from cool white to amber) to match your circadian
# rhythm.
#
#
# #### Hardware & Accessories
#
# Q: How durable is the stylus tips? A: The stylus tips are made of a durable felt-composite to mimic the feel of a pencil.
# A standard tip lasts 3-6 months depending on writing pressure. The package includes 5 replacement tips and a removal
# tool.
#
# Q: Is the device water-resistant? A: The SmartScribble is splash-resistant (IP52 rated), meaning it can handle light rain
# or a minor spill, but it should not be submerged.
#
#
# #### Software & Subscription
#
# Q: Is there a monthly fee for the AI features? A: The basic handwriting recognition and cloud sync are free forever.
# The "Advanced AI Expansion" (generative brainstorming) is free for the first year. After that, it is a strictly optional
# subscription of $4.99/month to cover cloud computing costs.
#
# <!-- PageBreak -->
#
# Q: How secure is my data? A: Security is paramount. All notes are encrypted at rest (AES-256) and in transit (TLS 1.3).
# Users can also password-protect specific folders or the entire device.
#
#
# #### Support & Warranty
#
# Q: What happens if I break the screen? A: E-Ink screens are delicate. We offer a standard 1-year manufacturer
# warranty covering defects. We highly recommend purchasing our "ScribbleCare+" protection plan ($49), which covers
# accidental damage, including screen drops, for two years.
#
# Q: What is the return policy? A: We are confident you will love the SmartScribble. If you are not satisfied, you may
# return the device in its original packaging within 30 days of receipt for a full refund, minus return shipping costs.
#
#
# #### Section 9: What's in the Box?
#
# 1\. SmartScribble AI Notebook (Graphite Grey)
#
# 2\. Scribble Pen Pro (Magnetic Stylus)
#
# 3\. Replacement Nibs (x5) and Nib Removal Tool
#
# 4\. USB-C to USB-A Braided Charging Cable (1.5m)
#
# 5\. Quick Start Guide
#
# 6\. Microfiber Cleaning Cloth
#
#
# #### Closing Statement
#
# The SmartScribble is more than a gadget; it is a commitment to your own thoughts. By clearing away the clutter of the
# modern web and focusing on the purity of the handwritten word-amplified by the intelligence of Al-we enable you to
# create your best work.
#
# SmartScribble. Your Ideas, Amplified.
#
#
# ### Would you like me to ...
#
# 1\. Draft a specific email marketing campaign targeting university students for this product?
#
# 2\. Create a User Manual section regarding how to use the specific "AI Expand" gestures?
#
# 3\. Generate a comparison table comparing SmartScribble to competitors like reMarkable or Kindle Scribe?

# %% [markdown]
# ## Embedding Setup

# %%
import os

os.environ['AZURE_OPENAI_ENDPOINT'] = '<endpoint>'
os.environ['AZURE_OPENAI_API_EMBEDDINGS_DEPLOYMENT_NAME']='text-embedding-3-large'
os.environ['AZURE_OPENAI_API_KEY']='<key>'
os.environ['AZURE_OPENAI_API_VERSION']="2024-02-01"


from langchain_openai.embeddings.azure import AzureOpenAIEmbeddings

embeddings = AzureOpenAIEmbeddings(
    azure_deployment="text-embedding-3-large", # e.g., "text-embedding-ada-002"
    model="text-embedding-3-large" # Or other deployed model like "text-embedding-3-small"
)

query_embedding = embeddings.embed_query("What is the capital of France?")
query_embedding
