# %%
# Notebook
# .py
# API
# Dockerfile to deploy

# %%
# Conda environment / uv
# Opik / langSmith (opensource)
# PDF parsing / pypdf / azure ai document intelligence / aws textract / gcp document ai
# Load into vector db
# Create evals for both agents
# Build the agents (db agent, rag agent, supervisor agent)
# Guardrails

# %%
conda create -n aiproject python=3.12

pip install -U langchain-community langchain pymupdf4llm
